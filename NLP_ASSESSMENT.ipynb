# %%
# Import all the required libraries
# Import all the required libraries
import pandas as pd
import numpy as np
import seaborn as sns
import warnings
import json

# %matplotlib inline
from sklearn.tree import DecisionTreeClassifier
from sklearn.metrics import classification_report,confusion_matrix
from sklearn.ensemble import RandomForestClassifier
from sklearn.linear_model import LogisticRegression
from sklearn.decomposition import NMF
from sklearn.feature_extraction.text import TfidfTransformer
from sklearn.model_selection import train_test_split
import itertools
from pprint import pprint

import nltk
nltk.download('stopwords')
nltk.download('wordnet')
nltk.download('punkt')
from nltk.corpus import stopwords
from nltk.tokenize import word_tokenize
from nltk.stem import WordNetLemmatizer
import missingno as msno
import re, nltk, spacy, string
import matplotlib.pyplot as plt
from sklearn.feature_extraction.text import CountVectorizer, TfidfVectorizer

warnings.filterwarnings('ignore')
pd.set_option('max_columns',50)
pd.set_option('max_rows',50)
# Out:
# [nltk_data] Downloading package stopwords to /root/nltk_data...
# [nltk_data]   Package stopwords is already up-to-date!
# [nltk_data] Downloading package wordnet to /root/nltk_data...
# [nltk_data]   Package wordnet is already up-to-date!
# [nltk_data] Downloading package punkt to /root/nltk_data...
# [nltk_data]   Package punkt is already up-to-date!

# %% [markdown]
# # Load the dataset

# %%
dataset_path = open("./drive/MyDrive/NLP_ASSIGNMENT/Client_data.json")
data = json.load(dataset_path)

#Convert the data into pandas dataframe
df =pd.json_normalize(data)

# %% [markdown]
# #Get the information about the dataframe

# %%
#Get the size of the dataset
df.shape
# Out:
# (78313, 22)

# %%
#Print the info about the datatypes and no of null data records
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 78313 entries, 0 to 78312
# Data columns (total 22 columns):
#  #   Column                             Non-Null Count  Dtype
# ---  ------                             --------------  -----
#  0   _index                             78313 non-null  object
#  1   _type                              78313 non-null  object
#  2   _id                                78313 non-null  object
#  3   _score                             78313 non-null  float64
#  4   _source.tags                       10900 non-null  object
#  5   _source.zip_code                   71556 non-null  object
#  6   _source.complaint_id               78313 non-null  object
#  7   _source.issue                      78313 non-null  object
#  8   _source.date_received              78313 non-null  object
#  9   _source.state                      76322 non-null  object
#  10  _source.consumer_disputed          78313 non-null  object
# ...

# %%
#Print the column names of the dataset
df.columns
# Out:
# Index(['_index', '_type', '_id', '_score', '_source.tags', '_source.zip_code',
#        '_source.complaint_id', '_source.issue', '_source.date_received',
#        '_source.state', '_source.consumer_disputed', '_source.product',
#        '_source.company_response', '_source.company', '_source.submitted_via',
#        '_source.date_sent_to_company', '_source.company_public_response',
#        '_source.sub_product', '_source.timely',
#        '_source.complaint_what_happened', '_source.sub_issue',
#        '_source.consumer_consent_provided'],
#       dtype='object')

# %%
#Print the head of the dataset
df.head()
# Out:
#                 _index      _type      _id  _score   _source.tags  \
# 0  complaint-public-v2  complaint  3211475     0.0           None
# 1  complaint-public-v2  complaint  3229299     0.0  Servicemember
# 2  complaint-public-v2  complaint  3199379     0.0           None
# 3  complaint-public-v2  complaint  2673060     0.0           None
# 4  complaint-public-v2  complaint  3203545     0.0           None
#
#   _source.zip_code _source.complaint_id                       _source.issue  \
# 0            90301              3211475   Attempts to collect debt not owed
# 1            319XX              3229299     Written notification about debt
# 2            77069              3199379  Other features, terms, or problems
# 3            48066              2673060      Trouble during payment process
# 4            10473              3203545                    Fees or interest
#
#        _source.date_received _source.state _source.consumer_disputed  \
# ...

# %%
df.tail()
# Out:
#                     _index      _type      _id  _score _source.tags  \
# 78308  complaint-public-v2  complaint  3105617     0.0         None
# 78309  complaint-public-v2  complaint  3091984     0.0         None
# 78310  complaint-public-v2  complaint  3133355     0.0         None
# 78311  complaint-public-v2  complaint  3110963     0.0         None
# 78312  complaint-public-v2  complaint  2001189     0.0         None
#
#       _source.zip_code _source.complaint_id  \
# 78308            08857              3105617
# 78309            934XX              3091984
# 78310            923XX              3133355
# 78311             None              3110963
# 78312             None              2001189
#
#                                            _source.issue  \
# 78308                                 Closing an account
# 78309                 Other features, terms, or problems
# 78310  Problem with a lender or other company chargin...
# ...

# %%
#Assign new column names
df.columns = ['index', 'type', 'id', 'score', 'tags', 'zip_code','complaint_id', 'issue', 'date_received',
       'state', 'consumer_disputed', 'product','company_response', 'company', 'submitted_via',
       'date_sent_to_company', 'company_public_response','sub_product', 'timely',
       'complaint_what_happened', 'sub_issue','consumer_consent_provided']

# %%
#Visualize the missing values across the columns in the dataframe
msno.matrix(df)

# %%
#Assign nan in place of blanks in the complaints column
df[df.loc[:, 'complaint_what_happened'] == ''] = np.nan

# %%
# Check if blank values still exist
df[df.loc[:, 'complaint_what_happened'] == '']
# Out:
#                      index       type       id  score            tags  \
# 0      complaint-public-v2  complaint  3211475    0.0            None
# 3      complaint-public-v2  complaint  2673060    0.0            None
# 4      complaint-public-v2  complaint  3203545    0.0            None
# 5      complaint-public-v2  complaint  3275312    0.0  Older American
# 6      complaint-public-v2  complaint  3238804    0.0            None
# ...                    ...        ...      ...    ...             ...
# 78304  complaint-public-v2  complaint  3080086    0.0            None
# 78305  complaint-public-v2  complaint  3103013    0.0  Older American
# 78306  complaint-public-v2  complaint  3099437    0.0            None
# 78307  complaint-public-v2  complaint  3156336    0.0            None
# 78308  complaint-public-v2  complaint  3105617    0.0            None
#
#       zip_code complaint_id  \
# 0        90301      3211475
# 3        48066      2673060
# 4        10473      3203545
# ...

# %%
df.shape
# Out:
# (78313, 22)

# %%
#Remove all rows where complaints column is nan
df = df[~df['complaint_what_happened'].isnull()]

# %%
msno.matrix(df)

# %%
df.shape
# Out:
# (78313, 22)

# %% [markdown]
# #Perform text cleaning for further analysis

# %%
# Convert complaint_what_happened column to string for performing text operations
df['complaint_what_happened'] = df['complaint_what_happened'].astype(str)

# %%
# Write your function here to clean the text and remove all the unnecessary elements.
def preprocess_text(sent):
    sent = sent.lower() # Text to lowercase
    pattern = '[^\w\s]' # Removing punctuation
    sent = re.sub(pattern, '', sent) 
    pattern = '\w*\d\w*' # Removing words with numbers in between
    sent = re.sub(pattern, '', sent) 
    return sent

# %%
df_clean = pd.DataFrame(df['complaint_what_happened'].apply(preprocess_text))

# %%
df_clean
# Out:
#                                  complaint_what_happened
# 0
# 1      good morning my name is xxxx xxxx and i apprec...
# 2      i upgraded my xxxx xxxx card in  and was told ...
# 3
# 4
# ...                                                  ...
# 78308
# 78309  on wednesday xxxxxxxx i called chas my xxxx xx...
# 78310  i am not familiar with xxxx pay and did not un...
# 78311  i have had flawless credit for  yrs ive had ch...
# 78312  roughly  years ago i closed out my accounts wi...
#
# [78313 rows x 1 columns]

# %%
# Import Textblob for extracting noun phrases
# !pip install textblob
from textblob import TextBlob

# %%
# Installing wordcloud
# !pip install wordcloud

from wordcloud import WordCloud, STOPWORDS, ImageColorGenerator

# %%
import pickle
import nltk
nltk.download('punkt')
nltk.download('averaged_perceptron_tagger')
import spacy
import en_core_web_sm
nlp = en_core_web_sm.load()
# Out:
# [nltk_data] Downloading package punkt to /root/nltk_data...
# [nltk_data]   Package punkt is already up-to-date!
# [nltk_data] Downloading package averaged_perceptron_tagger to
# [nltk_data]     /root/nltk_data...
# [nltk_data]   Package averaged_perceptron_tagger is already up-to-
# [nltk_data]       date!

# %%
#Write your function to Lemmatize the texts
def lemmmatize_text(text):
    sent = []
    doc = nlp(text)
    for token in doc:
        sent.append(token.lemma_)
    return " ".join(sent)

# %%
#Create a dataframe('df_clean') that will have only the complaints and the lemmatized complaints 
df_clean['complaint_lemmatized'] = df_clean['complaint_what_happened'].apply(lemmmatize_text)

# %%
df_clean
# Out:
#                                  complaint_what_happened  \
# 0
# 1      good morning my name is xxxx xxxx and i apprec...
# 2      i upgraded my xxxx xxxx card in  and was told ...
# 3
# 4
# ...                                                  ...
# 78308
# 78309  on wednesday xxxxxxxx i called chas my xxxx xx...
# 78310  i am not familiar with xxxx pay and did not un...
# 78311  i have had flawless credit for  yrs ive had ch...
# 78312  roughly  years ago i closed out my accounts wi...
#
#                                     complaint_lemmatized
# 0
# 1      good morning my name be xxxx xxxx and I apprec...
# 2      I upgrade my xxxx xxxx card in   and be tell b...
# 3
# 4
# ...                                                  ...
# 78308
# 78309  on wednesday xxxxxxxx I call chas my xxxx xxxx...
# 78310  I be not familiar with xxxx pay and do not und...
# 78311  I have have flawless credit for   yr I ve have...
# 78312  roughly   year ago I close out my account with...
#
# ...

# %%
#Function to extract the Parts of Speech from the data
def get_part_of_speech(data):
  sent=[]
  blob = TextBlob(data)
  sent = [word for (word,tag) in blob.tags if tag=='NN']
  return " ".join(sent)

# %%
# Extract Complaint after removing POS tags
df_clean['complaint_POS_removed'] = df_clean['complaint_lemmatized'].apply(get_part_of_speech)

# %%
df_clean
# Out:
#                                  complaint_what_happened  \
# 0
# 1      good morning my name is xxxx xxxx and i apprec...
# 2      i upgraded my xxxx xxxx card in  and was told ...
# 3
# 4
# ...                                                  ...
# 78308
# 78309  on wednesday xxxxxxxx i called chas my xxxx xx...
# 78310  i am not familiar with xxxx pay and did not un...
# 78311  i have had flawless credit for  yrs ive had ch...
# 78312  roughly  years ago i closed out my accounts wi...
#
#                                     complaint_lemmatized  \
# 0
# 1      good morning my name be xxxx xxxx and I apprec...
# 2      I upgrade my xxxx xxxx card in   and be tell b...
# 3
# 4
# ...                                                  ...
# 78308
# 78309  on wednesday xxxxxxxx I call chas my xxxx xxxx...
# 78310  I be not familiar with xxxx pay and do not und...
# 78311  I have have flawless credit for   yr I ve have...
# 78312  roughly   year ago I close out my account with...
#
# ...

# %% [markdown]
# #Exploratory Data Analysis

# %%
# Write your code here to visualise the data according to the 'Complaint' character length
char_len = [len(each_sent) for each_sent in df_clean['complaint_POS_removed']]

sns.displot(char_len, kind='hist', bins=60)
plt.xlabel("Complaint character length")
plt.ylabel("Total number of Complaints")
plt.title("Distribution of Complaint character length")
plt.show()

# %% [markdown]
# **Find the top 40 words by frequency among all the articles after processing the text.**

# %%
#Using a word cloud find the top 40 words by frequency among all the articles after processing the text
stopwords = set(STOPWORDS)
wordcloud = WordCloud(max_font_size=60, max_words=40, 
                      background_color="white", random_state=100, 
                      stopwords=stopwords).generate(str(df_clean['complaint_POS_removed']))
plt.figure(figsize=[12,12])
plt.imshow(wordcloud, interpolation="bilinear")
plt.axis("off")
plt.show()

# %%
#Removing -PRON- from the text corpus
df_clean['Complaint_clean'] = df_clean['complaint_POS_removed'].str.replace('-PRON-', '')

# %%
# Creating a function to extract top ngrams(unigram/bigram/trigram) based on the function inputs
def get_top_ngrams(text, n=None, ngram=(1,1)):
  vec = CountVectorizer(stop_words='english', ngram_range=ngram).fit(text)
  bagofwords = vec.transform(text)
  sum_words = bagofwords.sum(axis=0)
  words_frequency = [(word, sum_words[0, index]) for word, index in vec.vocabulary_.items()]
  words_frequency = sorted(words_frequency, key = lambda x: x[1], reverse=True)
  return words_frequency[:n]

# %%
top_30words = get_top_ngrams(df_clean['Complaint_clean'].values.astype('U'), n=30, ngram=(1,1))
df_unigram = pd.DataFrame(top_30words, columns=['unigram', 'count'])
df_unigram
# Out:
#         unigram  count
# 0       account  47499
# 1         chase  46704
# 2          xxxx  36550
# 3        credit  34138
# 4          card  29290
# 5          bank  28415
# 6       payment  21171
# 7          time  16039
# 8        charge  14994
# 9           day  12971
# 10     xxxxxxxx  12407
# 11        money  11962
# 12         loan  11006
# 13        check  10811
# 14       letter   9669
# 15        state   9668
# 16  information   9660
# 17       report   9049
# 18  transaction   8653
# 19          fee   8633
# 20       number   8629
# 21        month   8463
# 22         year   8293
# 23     mortgage   8195
# 24     customer   8164
# 25        claim   7841
# 26      balance   7744
# 27        phone   7720
# 28      service   7675
# 29      company   7628

# %%
# Plotting top 30 Unigrams
plt.figure(figsize=[20,6])
sns.barplot(x=df_unigram['unigram'], y=df_unigram['count'])
plt.xticks(rotation=45)
plt.xlabel("Unigram")
plt.ylabel("Count")
plt.title("Count of top 30 Unigrams")
plt.show()

# %%
#Print the top 10 words in the unigram frequency
df_unigram.head(10)
# Out:
#    unigram  count
# 0  account  47499
# 1    chase  46704
# 2     xxxx  36550
# 3   credit  34138
# 4     card  29290
# 5     bank  28415
# 6  payment  21171
# 7     time  16039
# 8   charge  14994
# 9      day  12971

# %%
#Write your code here to find the top 30 bigram frequency among the complaints in the cleaned datafram(df_clean). 
top_30words = get_top_ngrams(df_clean['Complaint_clean'].values.astype('U'), n=30, ngram=(2,2))
df_bigram = pd.DataFrame(top_30words, columns=['bigram', 'count'])
df_bigram
# Out:
#               bigram  count
# 0        credit card  12782
# 1      credit report   4003
# 2          xxxx xxxx   3931
# 3   customer service   3079
# 4       chase credit   2967
# 5         chase bank   2943
# 6       bank account   2777
# 7      chase account   2619
# 8      account chase   2595
# 9    account account   2413
# 10      account bank   1747
# 11  checking account   1646
# 12      card account   1605
# 13        debit card   1561
# 14      credit score   1541
# 15    account credit   1485
# 16     money account   1366
# 17   payment payment   1352
# 18        card chase   1299
# 19      account xxxx   1291
# 20        xxxx chase   1272
# 21      phone number   1266
# 22      business day   1263
# 23    credit account   1237
# 24    charge account   1215
# 25    account number   1176
# 26      xxxx account   1165
# 27      card company   1124
# 28         card card   1082
# 29  fraud department   1060

# %%
# Plotting top 30 Bigrams
plt.figure(figsize=[20,6])
sns.barplot(x=df_bigram['bigram'], y=df_bigram['count'])
plt.xticks(rotation=45)
plt.xlabel("Bigram")
plt.ylabel("Count")
plt.title("Count of top 30 Bigrams")
plt.show()

# %%
#Print the top 10 words in the bigram frequency
df_bigram.head(10)
# Out:
#              bigram  count
# 0       credit card  12782
# 1     credit report   4003
# 2         xxxx xxxx   3931
# 3  customer service   3079
# 4      chase credit   2967
# 5        chase bank   2943
# 6      bank account   2777
# 7     chase account   2619
# 8     account chase   2595
# 9   account account   2413

# %%
#Write your code here to find the top 30 trigram frequency among the complaints in the cleaned datafram(df_clean). 
top_30words = get_top_ngrams(df_clean['Complaint_clean'].values.astype('U'), n=30, ngram=(3,3))
df_trigram = pd.DataFrame(top_30words, columns=['trigram', 'count'])
df_trigram
# Out:
#                        trigram  count
# 0            chase credit card   2063
# 1          credit card account   1027
# 2          credit card company    991
# 3            credit card chase    634
# 4           credit card credit    514
# 5        inquiry credit report    480
# 6           charge credit card    422
# 7               xxxx xxxx xxxx    410
# 8          account credit card    401
# 9             card credit card    388
# 10            credit card bank    361
# 11            bank credit card    349
# 12     credit reporting agency    345
# 13        credit report credit    342
# 14            xxxx credit card    334
# 15        credit reporting act    328
# 16          credit card charge    306
# 17         credit card payment    296
# 18       account credit report    290
# 19            credit card xxxx    276
# 20       account chase account    273
# 21         credit card balance    261
# 22            credit card card    260
# 23  consumer protection bureau    247
# ...

# %%
plt.figure(figsize=[20,6])
sns.barplot(x=df_trigram['trigram'], y=df_trigram['count'])
plt.xticks(rotation=45)
plt.xlabel("Trigram")
plt.ylabel("Count")
plt.title("Count of top 30 Trigrams")
plt.show()

# %%
#Print the top 10 words in the trigram frequency
df_trigram.head(10)
# Out:
#                  trigram  count
# 0      chase credit card   2063
# 1    credit card account   1027
# 2    credit card company    991
# 3      credit card chase    634
# 4     credit card credit    514
# 5  inquiry credit report    480
# 6     charge credit card    422
# 7         xxxx xxxx xxxx    410
# 8    account credit card    401
# 9       card credit card    388

# %% [markdown]
# **Clean the data further as few records were having xxx in the text corpus which is not sure why it is present.It might be due to human error or maybe sensitive data so since its not in readable format so removing them from the text corpus is advised.**

# %%
df_clean['Complaint_clean'] = df_clean['Complaint_clean'].str.replace('xxxx','')

# %%
print(type(df_clean))
# Out:
# <class 'pandas.core.frame.DataFrame'>

# %%
df_clean.to_csv('preprocessed_data.csv')

# %% [markdown]
# # Convert the raw textual data into numerical format.

# %%
tfidf = TfidfVectorizer(min_df=2, max_df=0.95, stop_words='english')

# %%
doctermmatrix = tfidf.fit_transform(df_clean['Complaint_clean'])

# %%
doctermmatrix
# Out:
# <78313x7261 sparse matrix of type '<class 'numpy.float64'>'
# 	with 643149 stored elements in Compressed Sparse Row format>

# %%
# Apply Topic Modelling
from sklearn.decomposition import NMF

# %%
#Load your nmf_model with the n_components i.e 5
num_topics = 5

#keep the random_state =40
nmf_model = NMF(n_components=num_topics, random_state=40)

# %%
nmf_model.fit(doctermmatrix)
len(tfidf.get_feature_names())
# Out:
# 7261

# %%
H = nmf_model.components_       # Topic-term matrix

# %%
#Print the Top15 words for each of the topics
words = np.array(tfidf.get_feature_names())
topic_words = pd.DataFrame(np.zeros((num_topics, 15)), index=[f'Topic {i + 1}' for i in range(num_topics)],
                           columns=[f'Word {i + 1}' for i in range(15)]).astype(str)
for i in range(num_topics):
    ix = H[i].argsort()[::-1][:15]
    topic_words.iloc[i] = words[ix]

topic_words
# Out:
#           Word 1 Word 2    Word 3    Word 4       Word 5   Word 6   Word 7  \
# Topic 1  account  chase   balance  checking       branch   reason     fund
# Topic 2   credit   card    report   inquiry        score    chase  company
# Topic 3  payment   loan  mortgage     chase        month     time     home
# Topic 4   charge  chase      card       fee  transaction  dispute    fraud
# Topic 5     bank  check     money      fund      deposit      day    claim
#
#                Word 8       Word 9   Word 10      Word 11      Word 12  \
# Topic 1        access      deposit    number  information     business
# Topic 2         limit  application      bank         debt  information
# Topic 3  modification         year   balance         rate         date
# Topic 4         claim     purchase  merchant         time      service
# Topic 5   transaction         cash    branch         time       number
#
#          Word 13    Word 14   Word 15
# Topic 1    money        fee       day
# ...

# %% [markdown]
# **Observation Looking at the topics above,we can find that there are following main topic present in the text corpus.**
# Fraudalent reporting, Card
#
# 1.   Topic -1 Banking  Services
# 2.   Topic -2 Card
# 3.   Topic -3 Others
# 4.   Topic -4 Fraudalent  Reporting
# 5.   Topic -5 Loans

# %%
#Create the best topic for each complaint in terms of integer value 0,1,2,3 & 4
topic_results = nmf_model.transform(doctermmatrix)

# %%
#Assign the best topic to each of the cmplaints in Topic Column
df_clean['Topic'] = topic_results.argmax(axis=1)

# %%
df_clean.head()
# Out:
#                              complaint_what_happened  \
# 0
# 1  good morning my name is xxxx xxxx and i apprec...
# 2  i upgraded my xxxx xxxx card in  and was told ...
# 3
# 4
#
#                                 complaint_lemmatized  \
# 0
# 1  good morning my name be xxxx xxxx and I apprec...
# 2  I upgrade my xxxx xxxx card in   and be tell b...
# 3
# 4
#
#                                complaint_POS_removed  \
# 0
# 1  morning name stop bank cardmember service ask ...
# 2  card agent upgrade date agent information orde...
# 3
# 4
#
#                                      Complaint_clean  Topic
# 0                                                         0
# 1  morning name stop bank cardmember service ask ...      4
# 2  card agent upgrade date agent information orde...      0
# 3                                                         0
# 4                                                         0

# %%
#Print the first 5 Complaint for each of the Topics
df_clean_5=df_clean.groupby('Topic').head(5)
df_clean_5.sort_values('Topic')
# Out:
#                                complaint_what_happened  \
# 0
# 2    i upgraded my xxxx xxxx card in  and was told ...
# 3
# 4
# 5
# 26   i have reached out to xxxx several times in at...
# 15                       can you please remove inquiry
# 23   i have a chase credit card which is incorrectl...
# 10   chase card was reported on  however fraudulent...
# 11   on  while trying to book a xxxx  xxxx  ticket ...
# 20   during the summer months i experience a declin...
# 81   i bought a new xxxx xxxx on xxxxxxxx from xxxx...
# 73   i have wired through one of chase branches in ...
# 58   i made a purchase of  on xxxxxxxx i made payme...
# 57   i have been trying to do a loan modification w...
# 21   on xxxx  i made a  payment to an online retail...
# 30   to whom it may concern chase bank charged wron...
# 32   my chase amazon card was declined for a cateri...
# 43   chase sent me an email today with the innocuou...
# 45   i made a purchase with xxxx xxxx xxxx on  in t...
# ...

# %%
#Create a mapping of topics and topic names
Topic_names = { 0:"Banking Services", 1:"Card", 2:"Others",
               3:"Fraudalent Reporting", 4:"Loans" }
#Replace Topics with Topic Names
df_clean['Topic'] = df_clean['Topic'].map(Topic_names)

# %%
df_clean.head()
# Out:
#                              complaint_what_happened  \
# 0
# 1  good morning my name is xxxx xxxx and i apprec...
# 2  i upgraded my xxxx xxxx card in  and was told ...
# 3
# 4
#
#                                 complaint_lemmatized  \
# 0
# 1  good morning my name be xxxx xxxx and I apprec...
# 2  I upgrade my xxxx xxxx card in   and be tell b...
# 3
# 4
#
#                                complaint_POS_removed  \
# 0
# 1  morning name stop bank cardmember service ask ...
# 2  card agent upgrade date agent information orde...
# 3
# 4
#
#                                      Complaint_clean             Topic
# 0                                                     Banking Services
# 1  morning name stop bank cardmember service ask ...             Loans
# 2  card agent upgrade date agent information orde...  Banking Services
# 3                                                     Banking Services
# 4                                                     Banking Services

# %%
df_clean.shape
# Out:
# (78313, 5)

# %% [markdown]
# # Model Building

# %%
#Create the dictionary again of Topic names and Topics
# Banking Services", 1:"Card", 2:"Others",
              #  3:"Fraudalent Reporting", 4:"Loans"





Topic_names = { "Banking Services":0, "Card":1, "Others":2,
               "Fraudalent Reporting":3, "Loans":4 }
#Replace Topics with Topic Names
df_clean['Topic'] = df_clean['Topic'].map(Topic_names)

# %%
df_clean.shape
# Out:
# (78313, 5)

# %%
df_clean.columns
# Out:
# Index(['complaint_what_happened', 'complaint_lemmatized',
#        'complaint_POS_removed', 'Complaint_clean', 'Topic'],
#       dtype='object')

# %%
df_clean.head()
# Out:
#                              complaint_what_happened  \
# 0
# 1  good morning my name is xxxx xxxx and i apprec...
# 2  i upgraded my xxxx xxxx card in  and was told ...
# 3
# 4
#
#                                 complaint_lemmatized  \
# 0
# 1  good morning my name be xxxx xxxx and I apprec...
# 2  I upgrade my xxxx xxxx card in   and be tell b...
# 3
# 4
#
#                                complaint_POS_removed  \
# 0
# 1  morning name stop bank cardmember service ask ...
# 2  card agent upgrade date agent information orde...
# 3
# 4
#
#                                      Complaint_clean  Topic
# 0                                                         0
# 1  morning name stop bank cardmember service ask ...      4
# 2  card agent upgrade date agent information orde...      0
# 3                                                         0
# 4                                                         0

# %%
#Now that we have the labels columns lets discard the unneccesary rows and keep the rows which are useful for model training
dataset_useful = df_clean[['complaint_what_happened','Topic']]
dataset_useful.head(15)
# Out:
#                               complaint_what_happened  Topic
# 0                                                          0
# 1   good morning my name is xxxx xxxx and i apprec...      4
# 2   i upgraded my xxxx xxxx card in  and was told ...      0
# 3                                                          0
# 4                                                          0
# 5                                                          0
# 6                                                          0
# 7                                                          0
# 8                                                          0
# 9                                                          0
# 10  chase card was reported on  however fraudulent...      1
# 11  on  while trying to book a xxxx  xxxx  ticket ...      1
# 12                                                         0
# 13                                                         0
# ...

# %%
vect = CountVectorizer()
X_train_cnt = vect.fit_transform(dataset_useful['complaint_what_happened'])

# Save word vector
pickle.dump(vect.vocabulary_, open("count_vector.pk1", "wb"))

# %%
tfidf_transformer = TfidfTransformer()
X_train_tfidf = tfidf_transformer.fit_transform(X_train_cnt)

# Save tfidf
pickle.dump(tfidf_transformer, open('tfidf.pk1', "wb"))

# %%
#Train the model
from sklearn.linear_model import LogisticRegression
from sklearn.model_selection import train_test_split

# %%
#Split the dataset into training an testing
X_train, X_test, y_train, y_test = train_test_split(X_train_tfidf,
                                                    dataset_useful['Topic'],
                                                    test_size=0.25, 
                                                    random_state=42)

# %%
reg_models = LogisticRegression(random_state=44).fit(X_train,y_train)

# %%
reg_models.score(X_test,y_test)
# Out:
# 0.9659328872771847

# %%
pickle.dump(reg_models,open("logreg_model.pk1", "wb"))

# %%
# Load pickled model
logreg_model = pickle.load(open("logreg_model.pk1", "rb"))

# %%
# Make predictions on test data
y_pred = logreg_model.predict(X_test)

# %%
print(confusion_matrix(y_test,y_pred))
# Out:
# [[14905    27    11    28    49]
#  [   46  1023    18    60     3]
#  [   49    11  1096    18    13]
#  [   88    29    32  1043    27]
#  [   88     9    30    31   845]]

# %%
fig, ax = plt.subplots(figsize=(6, 6))
ax = sns.heatmap(confusion_matrix(y_test, y_pred),
                 annot=True,
                 cbar=False,
                 fmt = '0.1f')
plt.xlabel("Actual label")
plt.ylabel("Predicted label")
plt.show()

# %%
# # Banking Services", 1:"Card", 2:"Others",
              #  3:"Fraudalent Reporting", 4:"Loans"



Topicnames_target = ["Banking Services", "Card", "Others", "Fraudalent Reporting", "Loans"]

# %%
# Print Classification Report
print(classification_report(y_test, y_pred, target_names = Topicnames_target))
# Out:
#                       precision    recall  f1-score   support
#
#     Banking Services       0.98      0.99      0.99     15020
#                 Card       0.93      0.89      0.91      1150
#               Others       0.92      0.92      0.92      1187
# Fraudalent Reporting       0.88      0.86      0.87      1219
#                Loans       0.90      0.84      0.87      1003
#
#             accuracy                           0.97     19579
#            macro avg       0.92      0.90      0.91     19579
#         weighted avg       0.97      0.97      0.97     19579

# %% [markdown]
# # Decision Tree Classifier

# %%
# Importing DecisionTreeClassifier from sklearn
from sklearn.tree import DecisionTreeClassifier

# %%
X_train, X_test, y_train, y_test = train_test_split(X_train_tfidf,
                                                    dataset_useful['Topic'], 
                                                    test_size=0.30, 
                                                    random_state=42)

# %%
decision_tree_classifier =  DecisionTreeClassifier(random_state=42).fit(X_train, y_train)

# %%
decision_tree_classifier.score(X_test,y_test)
# Out:
# 0.9341959649272155

# %%
params = {"max_depth": [3, 5, 10],
           "min_samples_split": np.arange(2, 20, 2),
           "min_samples_leaf": np.arange(1, 20, 2)}

# %%
# Setup grid hyperparameter search for Decision Tree
from sklearn.model_selection import GridSearchCV
dt_hpt = GridSearchCV(DecisionTreeClassifier(random_state=42),
                                param_grid=params,
                                cv=5,
                                verbose=True,
                                n_jobs=-1)

# Fit random hyperparameter search model
dt_hpt.fit(X_train, y_train);
# Out:
# Fitting 5 folds for each of 270 candidates, totalling 1350 fits

# %%
dt_hpt.best_params_
# Out:
# {'max_depth': 10, 'min_samples_leaf': 3, 'min_samples_split': 2}

# %%
dt_hpt.score(X_test,y_test)
# Out:
# 0.93151442921597

# %% [markdown]
# With the tuned Decision Tree Model the accuracy is 77.03% which is less than the base Model's Accuracy which is 77.85%

# %%
pickle.dump(dt_hpt, open("dt_model.pk1", "wb"))

# %%
# Load pickled model
dt_model = pickle.load(open("dt_model.pk1", "rb"))

# %%
# Make predictions on test data
y_pred = dt_model.predict(X_test)

# %%
# Print Confusion Matrix
print(confusion_matrix(y_test, y_pred))
# Out:
# [[17745    46    24   116    58]
#  [   26  1129    56   134    41]
#  [   36    79  1101   136    69]
#  [   67   184    70  1067    92]
#  [  108    32    76   159   843]]

# %%
# Visualize Confusion Matrix with heatmap
fig, ax = plt.subplots(figsize=(6, 6))
ax = sns.heatmap(confusion_matrix(y_test, y_pred),
                 annot=True,
                 cbar=False, fmt = '0.1f')
plt.xlabel("Actual label")
plt.ylabel("Predicted label")
plt.show()

# %%
Topicnames_target = ["Bank account services", "Credit card / Prepaid card", "Others", "Theft/Dispute reporting", "Mortgages/loans"]

# %%
# Print Classification Report
print(classification_report(y_test, y_pred, target_names = Topicnames_target))
# Out:
#                             precision    recall  f1-score   support
#
#      Bank account services       0.99      0.99      0.99     17989
# Credit card / Prepaid card       0.77      0.81      0.79      1386
#                     Others       0.83      0.77      0.80      1421
#    Theft/Dispute reporting       0.66      0.72      0.69      1480
#            Mortgages/loans       0.76      0.69      0.73      1218
#
#                   accuracy                           0.93     23494
#                  macro avg       0.80      0.80      0.80     23494
#               weighted avg       0.93      0.93      0.93     23494
